# %% [markdown]
# Vector databases allow for fast comparison of embeddings
#
# Here I am going to use chromadb
#
# https://docs.trychroma.com/usage-guide

# %%
# %pip install chromadb

# %%
# read passages from a file
import json

with open('passages.jsonl', 'r') as f:
    passages = [json.loads(line) for line in f]

# %% [markdown]
# These passages are from #dealing_with_pdfs.ipynb

# %%
passages[0]
# Out:
# {'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Cybersecurity\\Application Security\\Security_slides08_Apps.pdf',
#  'page': 0,
#  'passage': ['Application \nSecurity\nMichał Szychowiak\n , PhD\nhttp s://www.cs.put.poznan.pl/mszychowiak'],
#  'embedding': [0.026378992944955826,
#   0.032453376799821854,
#   0.006036689970642328,
#   0.030262457206845284,
#   0.0931553840637207,
#   0.03764684870839119,
#   0.04652584716677666,
#   0.03759697824716568,
#   -0.009518101811408997,
#   -0.007155050523579121,
#   -0.01823224313557148,
#   0.0024533483665436506,
#   -0.04043308272957802,
#   0.007214752957224846,
#   -0.010217620059847832,
#   0.05745114013552666,
#   0.08077249675989151,
#   0.020502407103776932,
#   0.0024849968031048775,
#   -0.005711267236620188,
#   0.062455419450998306,
#   0.07145043462514877,
#   0.0598815493285656,
#   0.03083709441125393,
#   0.02414828911423683,
#   0.03239484876394272,
#   0.042618077248334885,
#   -0.006426290608942509,
#   -0.046566564589738846,
#   0.003730559954419732,
#   0.046498674899339676,
#   0.0010099626379087567,
#   -0.002702689031139016,
#   -0.014899362809956074,
#   0.009411050006747246,
#   0.0036315121687948704,
#   -0.008988196961581707,
#   0.009731994941830635,
#   0.003753948025405407,
#   0.031439848244190216,
#   -0.051264166831970215,
#   0.02374250814318657,
#   -0.04252561926841736,
#   -0.00041143078124150634,
#   -0.04565015062689781,
#   -0.015447099693119526,
#   -0.02158794179558754,
#   0.03524384647607803,
#   -0.013852108269929886,
#   -0.022318052127957344,
#   -0.06247755512595177,
#   0.012131788767874241,
#   -0.018078874796628952,
#   0.0018573467386886477,
#   -0.04101899638772011,
#   0.047500353306531906,
#   -0.004632433410733938,
#   -0.03801070526242256,
#   0.013676582835614681,
#   -0.053272925317287445,
#   -0.0045956894755363464,
#   -0.012685529887676239,
#   0.028432229533791542,
#   0.025863943621516228,
#   0.04270437732338905,
#   -0.012822012417018414,
#   0.012742836959660053,
#   0.04308620095252991,
#   -0.058972716331481934,
#   -0.001833565765991807,
#   -0.007635747082531452,
#   0.009002317674458027,
#   -0.01891237497329712,
#   -0.003927937243133783,
#   0.016167448833584785,
#   -0.055198777467012405,
#   0.0074677420780062675,
#   0.039940789341926575,
#   0.01639566197991371,
#   0.043058570474386215,
#   -0.01579740084707737,
#   -0.005713290069252253,
#   0.0025196089409291744,
#   0.025597626343369484,
#   -1.155158406618284e-05,
#   -0.044211842119693756,
#   -0.024044062942266464,
#   -0.009863912127912045,
#   -0.04773849621415138,
#   0.051804136484861374,
#   0.026962194591760635,
#   -0.040786679834127426,
#   0.024519596248865128,
#   0.05017520487308502,
#   0.013763602823019028,
#   0.0010443651117384434,
#   -0.006851055193692446,
#   -0.03234995901584625,
#   -0.0715155377984047,
#   -0.04411344975233078,
#   -0.03993917256593704,
#   -0.039149604737758636,
#   -0.018983833491802216,
#   -0.004150085151195526,
#   -0.010738406330347061,
#   -0.05520579591393471,
#   -0.008952217176556587,
#   -0.015217198990285397,
#   -0.017218133434653282,
#   0.057356562465429306,
#   -0.04578354209661484,
#   -0.043136414140462875,
#   0.022646872326731682,
#   0.013373063877224922,
#   0.010271169245243073,
#   0.015412394888699055,
#   0.05141715705394745,
#   -0.015666183084249496,
#   -0.017835021018981934,
#   -0.029256485402584076,
#   -0.04349231347441673,
#   0.056388214230537415,
#   0.020690975710749626,
#   0.024903181940317154,
#   -0.09409941732883453,
#   0.017056969925761223,
#   0.021219229325652122,
#   -0.037535425275564194,
#   -0.06324781477451324,
#   0.03764277324080467,
#   0.027221783995628357,
#   0.028388377279043198,
#   0.0690355971455574,
#   -0.00046123703941702843,
#   0.024848468601703644,
#   -0.02169513702392578,
#   -0.017979828640818596,
#   -0.02596518024802208,
#   0.02047114260494709,
#   0.03689616546034813,
#   -0.03409364074468613,
#   0.0898919627070427,
#   0.040563344955444336,
#   0.015083566308021545,
#   -0.04928101971745491,
#   -0.02338816598057747,
#   0.001927920151501894,
#   0.004054067190736532,
#   -0.03661824390292168,
#   0.020381202921271324,
#   -0.029276633635163307,
#   -0.07902946323156357,
#   0.020728377625346184,
#   0.024193091318011284,
#   -0.03893483430147171,
#   -0.05301198735833168,
#   0.0034449491649866104,
#   -0.044322460889816284,
#   0.03668428212404251,
#   0.026966562494635582,
#   -0.04304569587111473,
#   0.003108240431174636,
#   -0.044249873608350754,
#   0.006799665279686451,
#   -0.02088015526533127,
#   0.02749001421034336,
#   0.0007694141822867095,
#   0.01387179084122181,
#   0.04099182039499283,
#   -0.040067993104457855,
#   -0.022876007482409477,
#   -0.024890035390853882,
#   0.017858250066637993,
#   0.054281968623399734,
#   0.006519859191030264,
#   0.024153316393494606]}

# %%
documents = []
embeddings = []
metadatas = []

for passage in passages:
    if len(passage["passage"]) > 0:
        documents.append(passage["passage"][0])
        embeddings.append(
            passage['embedding']
        )
        metadatas.append({
            "path": passage['path'],
            "page": passage['page'],
        }
        )
    else:
        print(passage)
# Out:
# {'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\Social Networks\\social_networks_01_linked.pdf', 'page': 1, 'passage': [], 'embedding': [0.016788996756076813, -0.013808876276016235, -0.01604822464287281, 0.021892279386520386, 0.07405026257038116, 0.02662951871752739, 0.028776604682207108, 0.015657663345336914, -0.03983648121356964, -0.007657313719391823, 0.011292863637208939, 0.018824435770511627, -0.044349633157253265, 0.0019514847081154585, -0.005497219040989876, 0.07410973310470581, 0.07029037922620773, 0.0014849513536319137, 0.012235247530043125, -0.03864269703626633, 0.06009656563401222, 0.04208151996135712, 0.060616087168455124, 0.02429085597395897, 0.05661562457680702, 0.02079658955335617, 0.04402822256088257, -0.0012350984616205096
01582917757332325, 0.020670490339398384, -0.01850130967795849, -0.025400850921869278, 0.04770873114466667, -0.01845182478427887, 0.010123778134584427, 0.03494866564869881, -0.021003566682338715, -3.525544161675498e-05, 0.05430443584918976, 0.004844853188842535, 0.030193321406841278, 0.004790536593645811, 0.03024948388338089, 0.014803587459027767, 0.030419427901506424, -0.00036089320201426744, 0.0434998944401741, 0.03728869557380676, -0.009113232605159283, -0.01624772883951664, 0.03612108901143074, -0.02990869991481304, -0.014194413088262081, -0.0475953184068203, -0.029302343726158142, 0.0 ...

# %%
import chromadb
client = chromadb.Client()

client.list_collections()
# Out:
# []

# %%
len(embeddings)
# Out:
# 1453

# %%
collection = client.create_collection("sample_collection")

collection.add(
    documents=documents,
    embeddings=embeddings,
    metadatas=metadatas,
    ids=[f"{i}" for i in range(len(documents))] # in reality use a better method for ids e.g. a hash over a passage - this handles duplication
)

# %% [markdown]
# Key thing to note is to use the same model for query embeddings as for passage embeddings!

# %%
from fastembed.embedding import FlagEmbedding as Embedding


model = Embedding(model_name="BAAI/bge-base-en-v1.5", max_length=512)

# %% [markdown]
# Let's test some queries

# %%
query = "How does SPARQL syntax work?"
query_embedding = list(model.query_embed(query))[0].tolist()

# %%
collection.query(
    query_embedding,
)
# Out:
# {'ids': [['1420',
#    '1426',
#    '1444',
#    '1421',
#    '1424',
#    '1442',
#    '1423',
#    '1427',
#    '1437',
#    '1428']],
#  'distances': [[0.34534579515457153,
#    0.35128283500671387,
#    0.39873144030570984,
#    0.40308111906051636,
#    0.4037553369998932,
#    0.40621864795684814,
#    0.41147512197494507,
#    0.4136652648448944,
#    0.42037996649742126,
#    0.42296984791755676]],
#  'metadatas': [[{'page': 0,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 6,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 24,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 1,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 4,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 22,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 3,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 7,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 17,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 8,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'}]],
#  'embeddings': None,
#  'documents': [['SPARQL QUERYLANGUAGE',
#    'PREFIX  foo: <http://example.org/w1>…FROM …SELECT …WHERE {…}ORDER BY …Query patternDefinition of the data setResultspecificationPrefixdeclaration\nQuery modifierA SPARQL queryconsistsof ...',
#    'SELECTreturns a table of results (all or a subset of variables bound during query pattern matchingASKreturns a Boolean valueindicating whether the query pattern finds a match or notDESCRIBE returns an RDF graphthat describes the structure of the resources found (in a way that depends on the configuration of a given query engine -"surprise")CONSTRUCTreturns an RDF graph constructed by substituting variables in a set of triples templates (translation between different RDF graphs)SPARQL queryand answerformats',
#    'SPARQL ProtocolAndRDF Query Language•Pronunciation: like"sparkle"•Query languagefor RDF data•Protocol(HTTP, SOAP)SPARQL is…',
#    'SPARQL endpoint:•acceptsquerieson the input•as output, returnsresultsvia HTTP•mostlyrelatedto the sharingof a particularset of dataSPARQL endpoint',
#    '•SPARQL queriesareexecutedto RDF datasetsconsistingof RDF graphs•sofar, queriesissuedto the defaultgraph•RDF datasetsconsistof a defaultgraphand zero ormorenamedgraphs, identifiedby URIs•Namedgraphs: specifiedvia FROM NAMED clauses, ordefaultusinga givenSPARQL endpoint•GRAPH: allowsportionsof the queryto matchnamedgraphsin the RDF dataset, everythingoutsidethe GRAPH clauseismatchedto the defaultgraphData sources',
#    'The graphto whichwe issuethe query:SPARQL –mainidea (example)\nResults:Query pattern:\ngeo:hasPopulationgeo:Towngeo:Town',
#    '@prefix person: <http://example.org/person/> .',
#    'Logical:!,&&,||Arithmetic:+,-,*,/Comparison:=,!=,>,<, ...SPARQL tests:isURI,isBlank,isLiteral,boundSPARQL accessors:str,lang,datatypeOther:sameTerm,langMatches,regexFILTER –built-in functions',
#    '@prefix person: <http://example.org/person/> .']],
#  'uris': None,
#  'data': None}

# %%
query = "what versions of local search?"
query_embedding = list(model.query_embed(query))[0].tolist()

# %%
collection.query(
    query_embedding,
)
# Out:
# {'ids': [['1189',
#    '1178',
#    '1426',
#    '1448',
#    '1435',
#    '1436',
#    '1437',
#    '1104',
#    '1441',
#    '1440']],
#  'distances': [[0.5299314260482788,
#    0.6316799521446228,
#    0.6416252255439758,
#    0.663886308670044,
#    0.6649327874183655,
#    0.6657594442367554,
#    0.6669726371765137,
#    0.6676359176635742,
#    0.671486496925354,
#    0.6754134893417358]],
#  'metadatas': [[{'page': 97,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\Theory.pdf'},
#    {'page': 86,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\Theory.pdf'},
#    {'page': 6,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 28,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 15,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 16,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 17,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 12,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\Theory.pdf'},
#    {'page': 21,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'},
#    {'page': 20,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\SPARQL query language\\SPARQL - lecture - en(1).pdf'}]],
#  'embeddings': None,
#  'documents': [['Time and quality of local search results',
#    'The problem is difficult!',
#    'PREFIX  foo: <http://example.org/w1>…FROM …SELECT …WHERE {…}ORDER BY …Query patternDefinition of the data setResultspecificationPrefixdeclaration\nQuery modifierA SPARQL queryconsistsof ...',
#    '•SELECT expressions: resultscontainingvaluesderivedfrom constants, functioncallsorotherexpressions•Propertypaths: queriesof anypathlengthin the graphvia regularexpressions•Aggregation: groupingof resultsand calculationof aggregatedvalues(e.g.',
#    'FILTER@prefixdc: <http://purl.org/dc/elements/1.1/> .',
#    'FILTER@prefixdc: <http://purl.org/dc/elements/1.1/> .',
#    'Logical:!,&&,||Arithmetic:+,-,*,/Comparison:=,!=,>,<, ...SPARQL tests:isURI,isBlank,isLiteral,boundSPARQL accessors:str,lang,datatypeOther:sameTerm,langMatches,regexFILTER –built-in functions',
#    'Questions\n•What can we expect by using some algorithm A to optimize the \nfunction contained in the oracle?',
#    'UNION@prefixbook: <http://example.org/book/> .',
#    '@prefixbook: <http://example.org/book/> .']],
#  'uris': None,
#  'data': None}

# %% [markdown]
# This is not what we were looking for, sometimes results may make no sense.
#
# Let's try again with a "where specifier" to guide our search

# %%
collection.query(
    query_embedding,
    where_document={"$contains":"version"}
)
# Out:
# {'ids': [['889',
#    '888',
#    '899',
#    '1230',
#    '903',
#    '906',
#    '1283',
#    '1250',
#    '917',
#    '918']],
#  'distances': [[0.726885199546814,
#    0.7334774136543274,
#    0.7376772165298462,
#    0.7504379749298096,
#    0.7521195411682129,
#    0.7550857067108154,
#    0.7675451040267944,
#    0.774927020072937,
#    0.7796245813369751,
#    0.7843963503837585]],
#  'metadatas': [[{'page': 100,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\EC.pdf'},
#    {'page': 99,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\EC.pdf'},
#    {'page': 110,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\EC.pdf'},
#    {'page': 18,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\Knowledge Graphs\\Knowledge_graphs_en .pdf'},
#    {'page': 114,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\EC.pdf'},
#    {'page': 117,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\EC.pdf'},
#    {'page': 16,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\Ontologies\\RDFS_OWL_en(1).pdf'},
#    {'page': 26,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Semantic Web and Social Networks\\Knowledge Graphs\\Knowledge_graphs_en .pdf'},
#    {'page': 128,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\EC.pdf'},
#    {'page': 129,
#     'path': 'C:\\Users\\kryst\\Documents\\Stuff\\University\\Evolutionary Computation\\EC.pdf'}]],
#  'embeddings': None,
#  'documents': [['Local search in thegreedy version\n•The first improving solution is accepted\n•If the neighborhood (moves) are evaluated in a certain fixed order, \nthis may lead to a bias of the algorithm (e.g.',
#    'Local search in steepest and greedy versions \n(maximization assumed)\nGreedy version\nGenerate initial solution x\nrepeat\nfor each y\uf0ceN(x) in a random order\niff(y) > f(x) then\nx := y\nuntil no better solution was found after \nchecking the whole N(x)Steepest version\nGenerate initial solution x\nrepeat\nfind the best solution y \uf0ceN(x)\niff(y) > f(x) then\nx := y\nuntil no better solution was found after \nchecking the whole N(x)',
#    'Local search in steepest version\nGenerate an initial solution x\nrepeat\nfind the best move m\uf0ceM(x)\niff(m(x)) > f(x) then\nx := m(x)\nuntil no better solution was found after checking the whole M(x)',
#    'Google: Knowledge GraphsemanticsearchMay 2012: knowledgebaseusedby Google to expandsearchresultsmultipleknowledgesources: CIA World Factbook, Freebase, Wikipediasemanticweb containsmorethan570 millionobjectsand morethan18 billionfactsMay 2013: Polishlanguageversion; questionansweringratherthansearching, informationand linksbetweenfactsratherthana set of linksa system thatsearchesnot for keyphrases, but for the "entities" behindthe wordsenteredintothe searchengine',
#    'The use move evaluations (deltas) from previous \niterations of local search –vertex shift\n•Total number of new moves that need to be evaluated\n•\uf0bb4n2/ K\n•The complexity of one iteration with delta\n•\uf0bb(4n2/ K)\uf0b46 = 24n2/ K\n•Speed -uprelative to the base version with delta\n•\uf0bb(6n2) / (24n2/ K) = K / 4\n•Speed -uprelative to the base version with outdelta\n•\uf0bbn3/ (24n2/ K)= n \uf0b4K / 24\n•For n=1000, K = 100 (fully realistic in practice) speed -uprelative to the base \nversion without delta is 4166, and relative to the base version with delta is \n25 -without changing the results of the algorithm',
#    'The use move evaluations (deltas) from previous \niterations of local search –vertex shift\n•Total number of moves that need to be re -evaluated\n•\uf0bb8n\n•The complexity of one iteration with a delta\n•\uf0bb8n\uf0b46 = 48n\n•Speed -up relative to the base version with delta\n•\uf0bb(6n2) / (48n) = n / 8\n•Speed -up relative to the base version without delta\n•\uf0bbn3/ (48n)= n2/ 48\n•For n=1000, K = 100 (fully realistic in practice) spped -up relative to the base \nversion without a delta is 20833, and relative to the base version with a \ndelta is 125 -without changing the results of the algorithm',
#    'owl:Ontology<https://w3id.org/saref>rdf:typeowl:Ontology;dcterms:created"2015-02-10"^^xsd:date;dcterms:creator"Laura Daniele <mailto:laura.daniele@tno.nl>"^^xsd:string;dcterms:issued"2015-04-01"^^xsd:date;dcterms:license"This work is licensed under a Creative Commons Attribution License (version 3.0) <http://creativecommons.org/licenses/by/3.0/>"^^xsd:string;dcterms:publisher"TNO <https://www.tno.nl/nl/>"^^xsd:string;dcterms:title"SAREF: the Smart Appliances REFerenceontology"^^xsd:string;owl:importsgeo: ;owl:imports<http://www.w3.org/2006/time> ;owl:versionInfo"1.0"^^xsd:string;.',
#    '27From otherstructureddata formatsto knowledgegraphs•Relationaldatabases–specification of SQL queries and rendering of results as RDF–tools for mapping relational databases to RDF (D2RQ, ontop)•Web knowledgebases(DBPedia: data from Wikipedia)•Conversion of existingdata and extractionof RDF from: JPEG, Email, BibTex, Javadoc, Excel, …',
#    'Standard TSP neighborhood search –two-\nedge exchange –steepest version\nFor each vertex n1 from 0 to N -1\nFor each vertex n2 from n1+1 to N -1\nIfedges n1 -succ(n1) in2-succ(n2) are not adjacent\nEvaluate if move (n1, n2) brings improvement and is the best found so \nfar',
#    'TSP neighborhood search with candidate edges –\ntwo-edge exchange –steepest version\nFor each vertex n1 from 0 to N -1\nFor each vertex n2 from the list of the closest vertices to n1\nEvaluate all moves involving the addition of edge n1 -n2 and the removal of one \nof the edges adjacent to n1']],
#  'uris': None,
#  'data': None}

# %% [markdown]
# Now we got good results.
#
# Getting bad results is sometimes inevitable, no embedding model yet can model everything, but we need to have a way to fix that. Imagine being stuck in the interface that allows only for semantic search.
#
# When possible use problem structure to get better results. Here we know that the slide we were looking for contains string "version".
#
# ChromaDB allows for filtering on metadata as well https://docs.trychroma.com/usage-guide#querying-a-collection . One obvious suggestion here would be to put course name in metadata and this would fix our results as well

# %% [markdown]
# The holy grail of search is connecting old and new methods to:
#
# - allow for imprecise queries
# - allow for typos (techniques like levhenstein distance)
# - filtering on keywords
# - filtering on whatever metadata
#
#
# VectorDB's are effective at vector search, but they are not always designed for Full Text Search.
#
# Some important features of FTS
#
# - filtering out stopwords
# - lemmatization
# - handling typos
#
# e.g. If user forgets a stopword but looks for literal occurence "looking at the mountains" - "looking at mountains" we still want them to get proper results
#
# Some solutions I am aware of that allow hybrid approach:
# - https://www.elastic.co/guide/en/elasticsearch/reference/current/index.html
# - https://docs.cozodb.org/en/latest/tutorial.html <- though it may be too complicated
#
#
# I encourage you to do some digging about what features suit you best, for me ChromaDB handles everything that I need for my projects, and I don't have too much data so performance is not an issue. It is a good practice to calculate embeddings outside of VectorDB's api's.

# %% [markdown]
# Most vector db's will use a HNSW algorithm
#
# a good explanation is available here -> https://www.pinecone.io/learn/series/faiss/hnsw/
#
# Sometimes we want to set *ef_construction* in short it controls how dense our "small worlds" will be, quality/efficiency hyperparameter
